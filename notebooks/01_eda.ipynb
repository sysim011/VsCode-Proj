# %%
import pandas as pd

df = pd.read_csv("../data/sample_sales.csv")
df.head()
# Out:
#          date   product     category region  quantity  unit_price
# 0  2026-01-03  Notebook   Stationery  North        10         4.5
# 1  2026-01-05       Pen   Stationery   East        25         1.2
# 2  2026-01-07     Mouse  Electronics   West         5        18.0
# 3  2026-02-02  Keyboard  Electronics  North         4        35.0
# 4  2026-02-10  Notebook   Stationery  South        12         4.5
